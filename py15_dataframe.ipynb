# %% [markdown]
# <a href="https://colab.research.google.com/github/kim-dahun/python-study/blob/main/py15_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 패키지 임포트

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# tips 데이터 프레임

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# tips DataFrame
#
# * total_bill : 영수증 금액
#
# * tip : 팁
#
# * sex : 성별
#
# * smoker : 흡연 여부
#
# * day : 요일
#
# * time : 시간대
#
# * size : 일행 수(테이블의 손님 수)

# %% [markdown]
# ## 데이터 프레임의 기술 통계량(descriptive statistics)

# %%
tips.describe() # 숫자 타입 변수(컬럼) 기술 통계량
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# 카테고리 타입 변수(컬럼)의 기술 통계량 - 빈도수

# %%
tips.value_counts('sex')
# Out:
# sex
# Male      157
# Female     87
# dtype: int64

# %%
tips.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips.smoker.value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
tips.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %% [markdown]
# 영수증 금액이 최대인 행 출력
#
# 영수증 금액이 최소인 행 출력

# %%
tips[tips['total_bill']==tips.total_bill.max()]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3

# %%
tips[tips['total_bill']==tips.total_bill.min()]
# Out:
#     total_bill  tip     sex smoker  day    time  size
# 67        3.07  1.0  Female    Yes  Sat  Dinner     1

# %%
tips[(tips['total_bill']==tips.total_bill.max()) | (tips['total_bill']==tips.total_bill.min()) ]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 67         3.07   1.0  Female    Yes  Sat  Dinner     1
# 170       50.81  10.0    Male    Yes  Sat  Dinner     3

# %%
tips['sex'].unique()

for x in tips.sex.unique():

  tip_mean = tips[tips.sex==x].tip.mean()
  print(f'{x}:{round(tip_mean,2)}')
# Out:
# Female:2.83
# Male:3.09

# %% [markdown]
# # 성별에 따른 tips의 차이?
#
# * 남성 손님들이 준 tip의 평균, 여성 손님들이 준 tip의 평균.
#
# * 성별 tips의 최댓값
#
# * 성별 tips의 최솟값

# %% [markdown]
# # 흡연 여부에 따른 tip의 차이?
#
# * 흡연 여부 ( Yes/No ) 별 tip의 평균

# %% [markdown]
# # 요일에 따른 Tip의 차이?
#
# * 요일별 Tip의 평균을 계산

# %% [markdown]
# # 시간에 따른 TIp의 차이?
#
# * 시간 별 Tip의 평균

# %%
x = tips.groupby('sex')['tip'].mean()
x1 = pd.DataFrame(x)

# %%
x1
# Out:
#              tip
# sex
# Male    3.089618
# Female  2.833448

# %%
y = tips.groupby('sex')['tip'].min()
y1 = pd.DataFrame(y)

# %%
y1
# Out:
#         tip
# sex
# Male    1.0
# Female  1.0

# %%
z = tips.groupby('sex')['tip'].max() # Pandas Lib의 Series로 출력 GroupBy 인수는 인덱스, 이후 계산된 값은 원소
z1 = pd.DataFrame(z)

# %%
z1
# Out:
#          tip
# sex
# Male    10.0
# Female   6.5

# %%
x2 = tips.groupby(['smoker','sex'])['tip'].mean()

# %%
pd.DataFrame(x2)
# Out:
#                     tip
# smoker sex
# Yes    Male    3.051167
#        Female  2.931515
# No     Male    3.113402
#        Female  2.773519

# %%
x3 = tips.groupby(['day','sex'])['tip'].mean()
pd.DataFrame(x3)
# Out:
#                   tip
# day  sex
# Thur Male    2.980333
#      Female  2.575625
# Fri  Male    2.693000
#      Female  2.781111
# Sat  Male    3.083898
#      Female  2.801786
# Sun  Male    3.220345
#      Female  3.367222

# %%
x4 = tips.groupby(['time','sex'])['tip'].mean()
pd.DataFrame(x4)
# Out:
#                     tip
# time   sex
# Lunch  Male    2.882121
#        Female  2.582857
# Dinner Male    3.144839
#        Female  3.002115

# %%
x5 = tips.groupby(['sex','day','time'])['tip'].agg({'mean','max','min'})
x5
# Out:
#                         mean   min    max
# sex    day  time
# Male   Thur Lunch   2.980333  1.44   6.70
#             Dinner       NaN   NaN    NaN
#        Fri  Lunch   1.900000  1.58   2.20
#             Dinner  3.032857  1.50   4.73
#        Sat  Lunch        NaN   NaN    NaN
#             Dinner  3.083898  1.00  10.00
#        Sun  Lunch        NaN   NaN    NaN
#             Dinner  3.220345  1.32   6.50
# Female Thur Lunch   2.561935  1.25   5.17
#             Dinner  3.000000  3.00   3.00
#        Fri  Lunch   2.745000  2.00   3.48
#             Dinner  2.810000  1.00   4.30
#        Sat  Lunch        NaN   NaN    NaN
#             Dinner  2.801786  1.00   6.50
#        Sun  Lunch        NaN   NaN    NaN
#             Dinner  3.367222  1.01   5.20

# %% [markdown]
# # Group BY

# %%
# 성별 tip의 평균

for x in tips['sex'].unique():

  sex_mean = tips[tips.sex==x]['tip'].mean()
  print(sex_mean)
# Out:
# 2.8334482758620685
# 3.0896178343949043

# %% [markdown]
# ## 두 개 이상이 카테고리 별 GroupBy

# %%
# 성별, 흡연여부별 Tip의 평균

# %%
# 성별 요일별 tip의 평균

tips.groupby(['sex','day']).tip.mean()

for x in tips.sex.unique():

  for y in tips.day.unique():



    x6 = tips[(tips.sex==x) & (tips.day==y)]['tip'].mean()

    print(f'{x} / {y} = {x6}')
# Out:
# Female / Sun = 3.3672222222222223
# Female / Sat = 2.8017857142857143
# Female / Thur = 2.5756249999999996
# Female / Fri = 2.781111111111111
# Male / Sun = 3.2203448275862065
# Male / Sat = 3.0838983050847455
# Male / Thur = 2.9803333333333333
# Male / Fri = 2.693

# %%
# 성별 영수증, 팁의 평균.

tips.groupby('sex')['tip','total_bill'].agg({'mean','mean'})

for x in tips['sex'].unique():

  y=tips[tips['sex']==x][['total_bill','tip']].mean()

  print(f'{x} \n {y}')
# Out:
# Female
#  total_bill    18.056897
# tip            2.833448
# dtype: float64
# Male
#  total_bill    20.744076
# tip            3.089618
# dtype: float64
# <ipython-input-47-e7c28fc7516c>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   tips.groupby('sex')['tip','total_bill'].agg({'mean','mean'})

# %%
# 성별, 흡연 여부 별 영수증, 팁의 평균

tips.groupby(['sex','smoker'])[['tip','total_bill']].mean()

for x in tips.sex.unique():

  for y in tips.smoker.unique():

    z = tips[(tips.sex == x) & (tips.smoker == y)][['tip','total_bill']].mean()
    print(f'{x} / {y} \n {z}')
# Out:
# Female / No
#  tip            2.773519
# total_bill    18.105185
# dtype: float64
# Female / Yes
#  tip            2.931515
# total_bill    17.977879
# dtype: float64
# Male / No
#  tip            3.113402
# total_bill    19.791237
# dtype: float64
# Male / Yes
#  tip            3.051167
# total_bill    22.284500
# dtype: float64

# %% [markdown]
# ## 그룹별 2개 이상의 통계 함수 적용

# %%
# 성별 Tip의 평균, 최댓값, 중앙값, 최솟값



tips.groupby('sex')['tip'].agg({'mean','min','median','max'})
# Out:
# <ipython-input-65-406ed578b0fa>:3: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tips.median()
#          max      mean  median  min
# sex
# Male    10.0  3.089618    3.00  1.0
# Female   6.5  2.833448    2.75  1.0

# %%
# 성별 흡연 여부별 영수증과 팁의 평균과 표준편차

y = tips.groupby(['sex','smoker'])[['tip','total_bill']].agg(['mean','std'])
pd.DataFrame(y)
# Out:
#                     tip           total_bill
#                    mean       std       mean       std
# sex    smoker
# Male   Yes     3.051167  1.500120  22.284500  9.911845
#        No      3.113402  1.489559  19.791237  8.726566
# Female Yes     2.931515  1.219916  17.977879  9.189751
#        No      2.773519  1.128425  18.105185  7.286455
