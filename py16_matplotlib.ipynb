# %% [markdown]
# <a href="https://colab.research.google.com/github/kim-dahun/python-study/blob/main/py16_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 패키지 임포트

# %%
import numpy as np # ndarray
import pandas as pd # series, dataFrame
import matplotlib.pyplot as plt # visualization(시각화)
import seaborn as sns # visualization(시각화), Example Data(예제)

# %% [markdown]
# # 데이터 셋 준비

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# # `matplotlib.pyplot` 모듈을 사용한 시각화.

# %% [markdown]
# 1. `figure` 객체 생성
# 1. `figure` 객체에 subplot(axis)을 생성해서 추가
# 1. subplot에 그래프 그림
# 1. 그래프의 여러가지 옵션들을 설정
# 1. 그래프 보여주기

# %%
# 1. figure 객체 생성.
figure = plt.figure()

# 2. 생성된 figure 객체에 subplot(axis) 을 추가
# axis = figure.add_subplot(1,1,1) # row, column, index
axis = figure.add_subplot(111)
# figure.add_subplot(212)

# 3. subplot에 그래프 종류를 선택해서 그림.
axis.hist(x=tips['total_bill'],color='purple)

# 그래프의 옵션을 설정
axis.set_xlabel('TotalBIll')
axis.set_ylabel('Count')
axis.set_title('Total_Bill graph')
axis.grid()

# 그래프 보여주기
plt.show()

# %%
fig = plt.figure(figsize=(6,8))

ax1 = fig.add_subplot(211)

ax2 = fig.add_subplot(2,1,2) # add_subplot(212)

ax1.hist(x=tips.total_bill, color='red')

ax2.scatter(x=tips.total_bill, y=tips.tip)

# 4. 옵션
ax1.grid()
ax2.grid()

plt.show()

# %% [markdown]
# figure에 2개의 subplot을 좌우로 배치하고, hist, scatter 그래프를 그리기.

# %%
fig2 = plt.figure(figsize=(12,5))

ax3 = fig2.add_subplot(1,2,1)
ax4 = fig2.add_subplot(1,2,2)

ax3.hist(x=tips.total_bill, bins=60)
ax4.scatter(x=tips.total_bill, y=tips.tip)

ax3.set_xlabel('Total bill')
ax4.set_xlabel('Total bill')
ax4.set_ylabel('tip')

ax3.grid()
ax4.grid()

plt.show()

# %% [markdown]
# # `plt.subplots()` 함수
#
# figure 객체 생성 + subplot 추가

# %% [markdown]
# ## figure에 1개의 subplot이 있는 경우

# %%
# figure생성 + subplot 추가
fig, ax = plt.subplots()

# subplot에 그래프 그림.
ax.hist(x=tips.total_bill)

# 옵션


# 그래프 보여주기
plt.show()

# %% [markdown]
# ## subplot 2개를 상하로 배치

# %%
fig, ax = plt.subplots(nrows=2,figsize=(6,8))

# print(ax) subplot이 2개 이상인 경우 return value ax 는 subplot 들의 배열(ndarray)이 됨.

ax[0].hist(x=tips.total_bill)
ax[1].scatter(x=tips.total_bill, y=tips.tip)

plt.show()

# %% [markdown]
# # 2개의 subplot을 좌우로 배치

# %%
fig1, ax1 = plt.subplots(nrows=1, figsize=(8,6), ncols=2)

ax1[0].hist(x=tips.total_bill)
ax1[1].scatter(x=tips.total_bill, y=tips.tip)

plt.show()

# %% [markdown]
# # `pyplot` 모듈의 top-level 함수
#
# figure 생성 + subplot 1개 생성 + 그래프 종류

# %% [markdown]
# ## Histogram
#
# * 연속형 변수를 구간으로 나눠서, 그 구간 안에 포함된 자료의 개수를 막대의 높이로 표현한 그래프
# * 연속형 변수의 분포를 알 수 있음.

# %% [markdown]
# hist 함수 파라미터 :
#
# * x : x축에 사용할 변수이름. Histogram을 그리기 위한 자료.
# * bins : 막대 개수, 구간
# * color : 막대 안쪽을 채우는 색깔
# * edgecolor : 막대 테두리색
# * density : False - 개수 / True : 밀도,비율

# %%
# 1. figure 생성. 2. subplot 1개 생성. 3. histogram 그리기
plt.hist(x=tips.total_bill, color='lightgray', edgecolor="black", bins=10, density=True)

# 4. 옵션 설정
plt.xlabel('Total bill')
plt.ylabel('count')
plt.title('Histogram')
plt.grid()
# 5. 보여주기
plt.show()

# %% [markdown]
# ## Box plot(상자 그림)
#
# * 숫자 타입 변수(컬럼)의 기술 통계량(최소값, 25%, 50%, 75%, 최댓값)을 상자 모양으로 시각화.

# %%
tips.total_bill.describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
plt.boxplot(x=tips.total_bill)

plt.grid()
plt.ylabel('Total bill')

plt.show()

# %%
tips.tip.describe()
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: tip, dtype: float64

# %%
plt.boxplot(x=tips.tip)

plt.ylabel('tip')

plt.show()

# %% [markdown]
# ## 막대 그래프(Bar plot)
#
# 카테고리 타입의 빈도수를 막대로 표현한 그래프

# %%
gender_code = tips.sex.value_counts()

# %%
# 새로 막대 그래프
# x : 인덱스, height : 막대의 높이. 빈도수
plt.bar(x=gender_code.index, height=gender_code.values, width=0.1)

plt.show()

# %%
plt.barh(y=gender_code.index ,width=gender_code.values, height=0.3)

plt.show()

# %% [markdown]
# ### Ex 1. 요일별 빈도수 막대 그래프
#
# * 가로, 세로 모두 그려보기
#
# ### Ex 2. 흡연여부 빈도수 막대 그래프
#
# * 가로, 세로 모두 그려보기
#
# ### Ex 3. 식사인원 빈도수 막대 그래프
#
# * 가로, 세로 모두 그려보기
#
# ### Ex 4. 성별 tip의 boxplot을 하나의 subplot에 그려보기
#
# ### Ex 5. 시간별 tip의 boxplot을 하나의 subplot에 그려보기
#
# ### Ex 6. 요일별 tip의 boxplot을 하나의 subplot에 그려보기

# %%
dayc = tips.day.value_counts()

plt.bar(x=dayc.index, height=dayc.values, width=0.4)

plt.show()

plt.barh(y=dayc.index, width=dayc.values, height = 0.4)

plt.show()

# %%
smokc = tips.smoker.value_counts()

plt.bar(x=smokc.index, height=smokc.values, width=0.4)

plt.show()

plt.barh(y=smokc.index, width=smokc.values, height=0.4)

plt.show()

# %%
sizec = tips['size'].value_counts()

plt.bar(x=sizec.index, height=sizec.values, width=0.4)

plt.show()

plt.barh(y=sizec.index, width=sizec.values, height=0.4)

plt.show()

# %%
plotdata = []
plotname = []
plotcount = []
y = 1
for x in tips.sex.unique():

  catch = tips[tips['sex']==x]['tip']
  plotdata.append(catch)
  plotname.append(x)
  plotcount.append(y)
  y+=1

plt.boxplot(x=plotdata)
plt.xticks(plotcount,plotname)

plt.show()

# %%
plotdata = []
plotname = []
plotcount = []
y = 1
for x in tips.day.unique():

  catch = tips[tips['day']==x]['tip']
  plotdata.append(catch)
  plotname.append(x)
  plotcount.append(y)
  y+=1

plt.boxplot(x=plotdata)
plt.xticks(plotcount,plotname)

plt.show()

# %%
plotdata = []

plotcount = []
y = 1
for x in tips.time.unique():

  catch = tips[tips['time']==x]['tip']
  plotdata.append(catch)

  plotcount.append(y)
  y+=1

plt.boxplot(x=plotdata)
plt.xticks(plotcount,[x for x in tips.time.unique()])

plt.show()

# %% [markdown]
# ## 산점도(Scatter Plot)
#
# 두 변수(컬럼) 사이의 상관 관계를 파악하기 위해서 사용.

# %%
plt.scatter(x=tips.total_bill, y=tips.tip, alpha=0.3, s=55, color='dodgerblue', marker='s') # alpha 는 투명도 (0-1), s = 점의 크기, c=marker의 색상, marker = 통계 데이터(마커)의 모양 default = 'o',

plt.xlabel('total_bill')
plt.grid()
plt.ylabel('tip')
plt.show()

# %%
# tip ~ size 상관 관계

plt.scatter(x= tips.tip, y = tips['size'], s=10, c='purple')
plt.xlabel('tip')
plt.ylabel('size')
plt.grid()

# %% [markdown]
# ## 선 그래프(Line Plot)
#
# 주로 시계열 데이터(시간에 따라서 변하는 데이터 : 주가, 환율, 날씨, ... )를 시각화.

# %%
np.random.seed(1) # 난수 생성하는 순서.
df = pd.DataFrame(data = { 'time' : np.arange(1,11), # [1,2,3,4,...,11]
                          'price' : np.random.rand(10) # [0, 1.0) 범위 난수 10개를 갖는 1차원 배열
                           })

# %%
df
# Out:
#    time     price
# 0     1  0.417022
# 1     2  0.720324
# 2     3  0.000114
# 3     4  0.302333
# 4     5  0.146756
# 5     6  0.092339
# 6     7  0.186260
# 7     8  0.345561
# 8     9  0.396767
# 9    10  0.538817

# %%
# price ~ time

plt.plot(df.time, df.price, 'b*-')
# format 문자열 ( 3번째 arg ): 색깔, Markder 모양, 선의 종류
# 색깔 : b(lue), r(ed), g(reen), (blac)k ...
# 마커종류 : o, ^, v, *, s, +, ...
# 선 종류 : -(solid line), :(dotted line), --(dashed line), ...

plt.xlabel('time')
plt.ylabel('price')

plt.show()

# %%
plt.plot(df.time,df.price, c='crimson', marker='+', linestyle='--')

# %%
np.random.seed(1)
df = pd.DataFrame(data = {
    'time' : np.arange(1,11),
    'price1' : np.random.rand(10),
    'price2' : np.random.rand(10),
    'price3' : np.random.rand(10)


})
df
# Out:
#    time    price1    price2    price3
# 0     1  0.417022  0.419195  0.800745
# 1     2  0.720324  0.685220  0.968262
# 2     3  0.000114  0.204452  0.313424
# 3     4  0.302333  0.878117  0.692323
# 4     5  0.146756  0.027388  0.876389
# 5     6  0.092339  0.670468  0.894607
# 6     7  0.186260  0.417305  0.085044
# 7     8  0.345561  0.558690  0.039055
# 8     9  0.396767  0.140387  0.169830
# 9    10  0.538817  0.198101  0.878143

# %%
plt.plot(df.time, df.price1, 'bo-', label='price1')
plt.plot(df.time, df.price2, 'ro-', label='price2')
plt.plot(df.time, df.price3, 'go-', label='price3')
plt.legend() # 범례(legend) 를 화면에 표시하기
plt.grid()

plt.show()
